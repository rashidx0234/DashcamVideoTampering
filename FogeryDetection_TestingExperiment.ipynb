# %%
import joblib
import numpy as np
import cv2
import random
import os

filename = 'fogeryDetection3.sav'
path = "C:/Users/hpvic/Python/noise/"

loaded_model = joblib.load(path + filename)

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/UnseenData1.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: UnseenData1.mp4
# Total frames in the video submitted: 1213
# Test Images length: 10
# Image 1
# This image is in class: tampered
# ---
# Image 2
# This image is in class: tampered
# ---
# Image 3
# This image is in class: tampered
# ---
# Image 4
# This image is in class: original
# ---
# Image 5
# This image is in class: tampered
# ---
# Image 6
# This image is in class: original
# ---
# Image 7
# This image is in class: tampered
# ---
# Image 8
# This image is in class: tampered
# ---
# Image 9
# This image is in class: tampered
# ---
# Image 10
# This image is in class: original
# ---
# Overall result: Tampered

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/UnseenData2.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: UnseenData2.mp4
# Total frames in the video submitted: 305
# Test Images length: 10
# Image 1
# This image is in class: tampered
# ---
# Image 2
# This image is in class: tampered
# ---
# Image 3
# This image is in class: tampered
# ---
# Image 4
# This image is in class: tampered
# ---
# Image 5
# This image is in class: tampered
# ---
# Image 6
# This image is in class: tampered
# ---
# Image 7
# This image is in class: tampered
# ---
# Image 8
# This image is in class: tampered
# ---
# Image 9
# This image is in class: tampered
# ---
# Image 10
# This image is in class: tampered
# ---
# Overall result: Tampered

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/UnseenData3.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: UnseenData3.mp4
# Total frames in the video submitted: 1839
# Test Images length: 10
# Image 1
# This image is in class: tampered
# ---
# Image 2
# This image is in class: tampered
# ---
# Image 3
# This image is in class: tampered
# ---
# Image 4
# This image is in class: tampered
# ---
# Image 5
# This image is in class: tampered
# ---
# Image 6
# This image is in class: tampered
# ---
# Image 7
# This image is in class: tampered
# ---
# Image 8
# This image is in class: tampered
# ---
# Image 9
# This image is in class: tampered
# ---
# Image 10
# This image is in class: tampered
# ---
# Overall result: Tampered

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/UnseenData4.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: UnseenData4.mp4
# Total frames in the video submitted: 900
# Test Images length: 10
# Image 1
# This image is in class: tampered
# ---
# Image 2
# This image is in class: tampered
# ---
# Image 3
# This image is in class: tampered
# ---
# Image 4
# This image is in class: tampered
# ---
# Image 5
# This image is in class: tampered
# ---
# Image 6
# This image is in class: tampered
# ---
# Image 7
# This image is in class: tampered
# ---
# Image 8
# This image is in class: tampered
# ---
# Image 9
# This image is in class: tampered
# ---
# Image 10
# This image is in class: tampered
# ---
# Overall result: Tampered

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/UnseenData5.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: UnseenData5.mp4
# Total frames in the video submitted: 1106
# Test Images length: 10
# Image 1
# This image is in class: original
# ---
# Image 2
# This image is in class: original
# ---
# Image 3
# This image is in class: tampered
# ---
# Image 4
# This image is in class: tampered
# ---
# Image 5
# This image is in class: original
# ---
# Image 6
# This image is in class: original
# ---
# Image 7
# This image is in class: original
# ---
# Image 8
# This image is in class: original
# ---
# Image 9
# This image is in class: tampered
# ---
# Image 10
# This image is in class: original
# ---
# Overall result: Tampered

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/UnseenData6.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: UnseenData6.mp4
# Total frames in the video submitted: 1860
# Test Images length: 10
# Image 1
# This image is in class: original
# ---
# Image 2
# This image is in class: original
# ---
# Image 3
# This image is in class: original
# ---
# Image 4
# This image is in class: original
# ---
# Image 5
# This image is in class: original
# ---
# Image 6
# This image is in class: original
# ---
# Image 7
# This image is in class: original
# ---
# Image 8
# This image is in class: original
# ---
# Image 9
# This image is in class: original
# ---
# Image 10
# This image is in class: original
# ---
# Overall result: Original

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/Video1.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: Video1.mp4
# Total frames in the video submitted: 1866
# Test Images length: 10
# Image 1
# This image is in class: tampered
# ---
# Image 2
# This image is in class: tampered
# ---
# Image 3
# This image is in class: tampered
# ---
# Image 4
# This image is in class: tampered
# ---
# Image 5
# This image is in class: tampered
# ---
# Image 6
# This image is in class: original
# ---
# Image 7
# This image is in class: tampered
# ---
# Image 8
# This image is in class: tampered
# ---
# Image 9
# This image is in class: tampered
# ---
# Image 10
# This image is in class: tampered
# ---
# Overall result: Tampered

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/Video2.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: Video2.mp4
# Total frames in the video submitted: 5400
# Test Images length: 10
# Image 1
# This image is in class: original
# ---
# Image 2
# This image is in class: original
# ---
# Image 3
# This image is in class: original
# ---
# Image 4
# This image is in class: original
# ---
# Image 5
# This image is in class: original
# ---
# Image 6
# This image is in class: original
# ---
# Image 7
# This image is in class: original
# ---
# Image 8
# This image is in class: original
# ---
# Image 9
# This image is in class: tampered
# ---
# Image 10
# This image is in class: original
# ---
# Overall result: Original

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/Video3.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: Video3.mp4
# Total frames in the video submitted: 426
# Test Images length: 10
# Image 1
# This image is in class: original
# ---
# Image 2
# This image is in class: original
# ---
# Image 3
# This image is in class: original
# ---
# Image 4
# This image is in class: original
# ---
# Image 5
# This image is in class: original
# ---
# Image 6
# This image is in class: original
# ---
# Image 7
# This image is in class: original
# ---
# Image 8
# This image is in class: original
# ---
# Image 9
# This image is in class: original
# ---
# Image 10
# This image is in class: original
# ---
# Overall result: Original

# %%
testImages = []
tampered_count = 0  # Counter for number of "Tampered" images

# Open the video file
video_path = "C:/Users/hpvic/Python/VideoForgery/UnseenData/Video3.mp4"
vidcap = cv2.VideoCapture(video_path)

video_filename = os.path.basename(video_path) 
print("Video Submitted:", video_filename)  # Display the video path

frameCount = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
print("Total frames in the video submitted:", frameCount) # Display total number of frames


# Select 10 random frame indices
randomFrameIndices = random.sample(range(frameCount), 10)

for frameIndex in sorted(randomFrameIndices):
    # Set the position of the video to the start of the frame
    vidcap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)

    # Read the frame
    success, image = vidcap.read()
    if not success:
        print("Error reading frame.")
        continue

    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (1920, 1080), interpolation=cv2.INTER_LINEAR)
    image = cv2.fastNlMeansDenoising(image, None, 10, 7, 21)

    # Append the image to the testImages array
    testImages.append(image)

# Print the lengths of the arrays to verify
print("Test Images length:", len(testImages))

combine = np.array(testImages)

combine = combine.reshape(combine.shape[0], combine.shape[1] * combine.shape[2])

for i in range(len(combine)):
    result = loaded_model.predict([combine[i]])[0]  # Directly access the first (and only) item in the list
    print("Image", i + 1)
    print("This image is in class:", result)
    print("---")
    if result.lower() == "tampered":
        tampered_count += 1
    
# If more than or equal to 20% of the images are "Tampered", classify the overall result as "Tampered"
if tampered_count / len(testImages) >= 0.2:
    print("Overall result: Tampered")
else:
    print("Overall result: Original")
# Out:
# Video Submitted: Video3.mp4
# Total frames in the video submitted: 426
# Test Images length: 10
# Image 1
# This image is in class: original
# ---
# Image 2
# This image is in class: original
# ---
# Image 3
# This image is in class: original
# ---
# Image 4
# This image is in class: original
# ---
# Image 5
# This image is in class: original
# ---
# Image 6
# This image is in class: original
# ---
# Image 7
# This image is in class: original
# ---
# Image 8
# This image is in class: original
# ---
# Image 9
# This image is in class: original
# ---
# Image 10
# This image is in class: original
# ---
# Overall result: Original
